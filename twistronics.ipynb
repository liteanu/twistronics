# %%
from math import cos, sin, pi, log, exp, sqrt, atan, acos
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms as mtrans

# %%
def sheet_b(angle):
    return plt.scatter(xx, yy, s=5, c='r', transform=mtrans.Affine2D().rotate(angle) + ax.transData)

fig, ax = plt.subplots(1,1, figsize=(10,10))
xx, yy = np.meshgrid(np.arange(-20, 20), np.arange(-20, 20))
plt.scatter(xx,yy,s=5, c='b')
sheet_b(pi/6)
plt.xlim(-20,20)
plt.ylim(-20,20)
plt.gca().set_aspect('equal', adjustable='box')
